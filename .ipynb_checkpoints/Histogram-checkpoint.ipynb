# %% [markdown]
# # Histogram

# %%
import matplotlib.pyplot as plt
x=[123,342,233,422,334,234]
c=[23,43,42,23,33,45]

plt.hist(x,histtype="stepfilled")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 5
#       2 x=[123,342,233,422,334,234]
#       3 c=[23,43,42,23,33,45]
# ----> 5 plt.hist(x,histtype="stepfilled",cmap=c)
#       6 plt.show()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\matplotlib\pyplot.py:3221, in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    3196 @_copy_docstring_and_deprecators(Axes.hist)
#    3197 def hist(
#    3198     x: ArrayLike | Sequence[ArrayLike],
#    (...)
#    3219     BarContainer | Polygon | list[BarContainer | Polygon],
#    3220 ]:
# -> 3221     return gca().hist(
#    3222         x,
#    3223         bins=bins,
#    3224         range=range,
#    3225         density=density,
#    3226         weights=weights,
#    3227         cumulative=cumulative,
# ...
