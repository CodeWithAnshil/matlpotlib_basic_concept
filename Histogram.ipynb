# %%
import matplotlib.pyplot as plt
import numpy as np
import random
num=np.random.randint(10,50,(40))
print(num)
# Out:
# [45 17 42 33 14 19 40 29 13 20 13 25 10 41 20 21 24 19 18 12 38 31 45 19
#  15 35 24 38 45 28 12 34 27 35 33 32 28 47 21 27]

# %%
no=[16,24, 41, 40, 19, 44, 42, 34, 36, 49, 22, 25, 30, 38, 30, 10, 17, 40, 13, 49, 11, 35, 15, 37,
    21, 38, 33, 15, 11, 33, 12, 26, 24, 41, 16, 20, 26,18, 19, 27]

bin=[10,20,30,40,50,60]
plt.hist(no,bins=bin,color='pink',edgecolor='b')

plt.title("Histogram",fontsize=15)
plt.xlabel("Range",fontsize=16)
plt.ylabel("No.",fontsize=15)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
